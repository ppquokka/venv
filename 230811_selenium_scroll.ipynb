# %%
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

# %%
# 페이지 이동
url = "https://blog.naver.com/PostView.naver?blogId=chunsa0127&logNo=222439908488&from=search&redirect=Log&widgetTypeCall=true&directAccess=false"
browser.get(url)

# %%
# 지정한 위치로 스크롤 내리기
# 모니터(해상도) 높이인 1080 위치로 스크롤 내리기
browser.execute_script("window.scrollTo(0, 1080)") # 1920 x 1080
browser.execute_script("window.scrollTo(0, 2080)")

# %%
# 화면 가장 아래로 스크롤 내리기
# browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 3 # 3초에 한번씩 스크롤 내림

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

# 반복 수행
while True:
    # 스크롤을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    # 페이지 로딩 대기
    time.sleep(interval)

    # 현재 문서 높이를 가져와서 저장
    curr_height = browser.execute_script("return document.body.scrollHeight")
    if curr_height == prev_height:
        break

    prev_height = curr_height

print("스크롤 완료")
# Out:
# 스크롤 완료

# %%
#browser.page_source :최종 html

# %%
import requests
from bs4 import BeautifulSoup
#res=requests.get(url)
#soup=BeautifulSoup(res.text,"lxml")
soup = BeautifulSoup(browser.page_source, "lxml")

# %%
soup
# Out:
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36" lang="ko"><head>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="always" name="referrer"/>
# <!--[if ie]>
# <style type="text/css">
# html {overflow: scroll; overflow-x: auto;}
# </style>
# <![endif]-->
# <link charset="UTF-8" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/LayoutTopCommon-495218781_https.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/t.static.blog/mylog/versioning//common/css/music/player-d3fc09e_https.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?3" rel="shortcut icon" type="image/x-icon"/>
# <meta content="[python] YOLO V3와 MobileNet V2를 활용한 축구 영상 Object Detection Model (openCV &amp; tensorflow)" property="og:title"/>
# ...

# %%
url="https://www.google.com/search?sca_esv=555605304&sxsrf=AB5stBjFzCuwCKueUrFm7EKjvb15ypAseA:1691698219734&q=%EC%BD%94%EB%81%BC%EB%A6%AC&tbm=isch&source=lnms&sa=X&ved=2ahUKEwi1-9D78tKAAxWNPXAKHQEFBqQQ0pQJegQIDhAB&biw=855&bih=917&dpr=1.5"

# %%
browser = webdriver.Chrome()
browser.get(url)

# %%
# 화면 가장 아래로 스크롤 내리기
# browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

import time
interval = 3 # 5초에 한번씩 스크롤 내림

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

# 반복 수행
while True:
    # 스크롤을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    # 페이지 로딩 대기
    time.sleep(interval)

    # 현재 문서 높이를 가져와서 저장
    curr_height = browser.execute_script("return document.body.scrollHeight")
    if curr_height == prev_height:
        break

    prev_height = curr_height

print("스크롤 완료")
# Out:
# 스크롤 완료

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(browser.page_source, "html.parser")

# %%
browser.close()

# %%
import os
if not os.path.exists("elephants"):
    os.makedirs("elephants")

# %%
len(soup.find_all("img"))
# Out:
# 837

# %%
img_set=soup.find_all("img")
import requests
k=0

for i, img in enumerate(img_set):
    try:
        res=requests.get(img["src"])   
        with open(f"./elephants/elephant_{i}.jpg", "wb") as f:
            f.write(res.content)
        k+=1    
    except:
        continue
    
print(k)
# Out:
# 618

# %%
url="https://www.google.com/search?q=%EA%B3%A0%EC%96%91%EC%9D%B4&tbm=isch&ved=2ahUKEwiS7eKm39OAAxU-qFYBHRfjBiUQ2-cCegQIABAA&oq=rhdiddl&gs_lcp=CgNpbWcQARgAMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMgUIABCABDoECAAQAzoICAAQsQMQgwE6CwgAEIAEELEDEIMBUKIKWNwUYM8kaABwAHgAgAFiiAH6BZIBATiYAQCgAQGqAQtnd3Mtd2l6LWltZ8ABAQ&sclient=img&ei=xbXVZNL2Db7Q2roPl8abqAI&bih=948&biw=854"
browser = webdriver.Chrome()
browser.get(url)
import time
interval = 3 # 5초에 한번씩 스크롤 내림

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

# 반복 수행
while True:
    # 스크롤을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

    # 페이지 로딩 대기
    time.sleep(interval)

    # 현재 문서 높이를 가져와서 저장
    curr_height = browser.execute_script("return document.body.scrollHeight")
    if curr_height == prev_height:
        break

    prev_height = curr_height

print("스크롤 완료")
soup = BeautifulSoup(browser.page_source, "html.parser")
browser.close()
# Out:
# 스크롤 완료
